# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',None)

# %%
#load dataset
df = pd.read_csv('/Users/aryaapalande/Desktop/Superstore_sales_project/superstore_data_raw/People-Table 1.csv')

# %%
#preview dataset
df.head()
# Out:
#     Regional Manager   Region  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0    Sadie Pawthorne     West         NaN         NaN         NaN
# 1        Chuck Magee     East         NaN         NaN         NaN
# 2  Roxanne Rodriguez  Central         NaN         NaN         NaN
# 3        Fred Suzuki    South         NaN         NaN         NaN

# %%
#dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Regional Manager  4 non-null      object
#  1   Region            4 non-null      object
#  2   Unnamed: 2        0 non-null      float64
#  3   Unnamed: 3        0 non-null      float64
#  4   Unnamed: 4        0 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 292.0+ bytes

# %%
df.columns
# Out:
# Index(['Regional Manager', 'Region', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df.shape
# Out:
# (4, 5)

# %%
df.describe(include='all')
# Out:
#        Regional Manager Region  Unnamed: 2  Unnamed: 3  Unnamed: 4
# count                 4      4         0.0         0.0         0.0
# unique                4      4         NaN         NaN         NaN
# top     Sadie Pawthorne   West         NaN         NaN         NaN
# freq                  1      1         NaN         NaN         NaN
# mean                NaN    NaN         NaN         NaN         NaN
# std                 NaN    NaN         NaN         NaN         NaN
# min                 NaN    NaN         NaN         NaN         NaN
# 25%                 NaN    NaN         NaN         NaN         NaN
# 50%                 NaN    NaN         NaN         NaN         NaN
# 75%                 NaN    NaN         NaN         NaN         NaN
# max                 NaN    NaN         NaN         NaN         NaN

# %%
#check null values
df.isnull().sum()
# Out:
# Regional Manager    0
# Region              0
# Unnamed: 2          4
# Unnamed: 3          4
# Unnamed: 4          4
# dtype: int64

# %%
#duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove unncessary columns
df = df[['Regional Manager','Region']]

# %%
df.columns
# Out:
# Index(['Regional Manager', 'Region'], dtype='object')

# %%
#count unique 
df.nunique()
# Out:
# Regional Manager    4
# Region              4
# dtype: int64

# %%
#frequency count
df['Region'].value_counts()
# Out:
# Region
# West       1
# East       1
# Central    1
# South      1
# Name: count, dtype: int64

# %%
#save cleaned dataset
df.to_csv("/Users/aryaapalande/Desktop/Superstore_sales_project/superstore_data_cleaned/people_cleaned.csv", index=False)

# %%
import os
from sqlalchemy import create_engine

MYSQL_USER = os.getenv("MYSQL_USER")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_HOST = os.getenv("MYSQL_HOST", "localhost")
MYSQL_DATABASE = os.getenv("MYSQL_DATABASE", "superstore")

engine = create_engine(
    f"mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}/{MYSQL_DATABASE}"
)

# %%
df.to_sql(
    'People',
    engine,
    if_exists='replace',
    index=False
)

print("Orders data successfully loaded into MySQL.")
# Out:
# Orders data successfully loaded into MySQL.

# %%
import pandas as pd
pd.read_sql("SELECT COUNT(*) AS total_rows FROM Orders", engine)
# Out:
#    total_rows
# 0       10194

# %%
pd.read_sql("SELECT * FROM Orders LIMIT 5", engine)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05 2023-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City State/Province  \
# 0  Darren Powers     Consumer  United States       Houston          Texas
# 1  Phillina Ober  Home Office  United States    Naperville       Illinois
# 2  Phillina Ober  Home Office  United States    Naperville       Illinois
# 3  Phillina Ober  Home Office  United States    Naperville       Illinois
# 4     Mick Brown     Consumer  United States  Philadelphia   Pennsylvania
#
# ...
